# %% [markdown]
# ## Parse the grammar and consider only chord-related information

# %%
from pathlib import Path
import os

grammar_path = Path('../grammar/')
test_grammar = Path('../grammar/abc/abc_music21.lark')

all_grammars = {}
for path, dirs, files in os.walk(grammar_path):
    for file in files:
        if file.endswith('.lark'):
            grammar_dict = {}
            with open(Path(path) / file, 'r') as g:
                start = False
                for line in g:
                    if 'shorthand' in line:
                        start = True
                        next(g)
                        continue
                    if start:
                        if line[:1] != '/' and line != '\n' and '?' not in line:
                            label, shorthands = line.split(':')
                            shorts = [x.replace('\n', '').strip(' ').strip('"') for x in shorthands.split('|')]
                            grammar_dict[label] = shorts

            all_grammars[file] = grammar_dict

all_grammars
# Out:
# {'abc_music21.lark': {'major': ['', 'M', 'maj'],
#   'minor': ['m', 'min'],
#   'augmented': ['+', 'aug'],
#   'diminished': ['dim', 'o'],
#   'dominant_seventh': ['7', 'dom7'],
#   'major_seventh': ['maj7', 'M7'],
#   'minor_major_seventh': ['mM7', 'm#7', 'minmaj7'],
#   'minor_seventh': ['m7', 'min7'],
#   'augmented_major_seventh': ['+M7', 'augmaj7'],
#   'augmented_seventh': ['7+', '+7', 'aug7'],
#   'half_diminished_seventh': ['ø7', 'm7b5'],
#   'diminished_seventh': ['o7', 'dim7'],
#   'seventh_flat_five': ['dom7dim5'],
#   'major_sixth': ['6'],
#   'minor_sixth': ['m6', 'min6'],
#   'major_ninth': ['M9', 'Maj9'],
#   'dominant_ninth': ['9', 'dom9'],
#   'minor_major_ninth': ['mM9', 'minmaj9'],
#   'minor_ninth': ['m9', 'min9'],
#   'augmented_major_ninth': ['+M9', 'augmaj9'],
#   'augmented_dominant_ninth': ['9#5', '+9', 'aug9'],
#   'half_diminished_ninth': ['ø9'],
#   'half_diminished_minor_ninth': ['øb9'],
#   'diminished_ninth': ['o9', 'dim9'],
#   'diminished_minor_ninth': ['ob9', 'dimb9'],
#   'dominant_11th': ['11', 'dom11'],
#   'major_11th': ['M11', 'Maj11'],
#   'minor_major_11th': ['mM11', 'minmaj11'],
#   'minor_11th': ['m11', 'min11'],
#   'augmented_major_11th': ['+M11', 'augmaj11'],
#   'augmented_11th': ['+11', 'aug11'],
#   'half_diminished_11th': ['ø11'],
#   'diminished_11th': ['o11', 'dim11'],
#   'major_13th': ['M13', 'Maj13'],
#   'dominant_13th': ['13', 'dom13'],
#   'minor_major_13th': ['mM13', 'minmaj13'],
#   'minor_13th': ['m13', 'min13'],
#   'augmented_major_13th': ['+M13', 'augmaj13'],
#   'augmented_dominant_13th': ['+13', 'aug13'],
#   'half_diminished_13th': ['ø13'],
#   'suspended_second': ['sus2'],
#   'suspended_fourth': ['sus', 'sus4'],
#   'suspended_fourth_seventh': ['7sus', '7sus4'],
#   'neapolitan': ['N6'],
#   'italian': ['It+6', 'It'],
#   'french': ['Fr+6', 'Fr'],
#   'german': ['Gr+6', 'Ger'],
#   'pedal': ['pedal'],
#   'power': ['power'],
#   'tristan': ['tristan'],
#   'subtract_degree': ['subtract" altered_degree'],
#   'alter_degree': ['alter" altered_degree'],
#   'add_degree': ['add" altered_degree'],
#   'slash': ['/" altered_note']},
#  'leadsheet_weimar.lark': {'major': ['', 'M', 'maj', 'j'],
#   'minor': ['m', 'min', '-'],
#   'augmented': ['+', 'aug'],
#   'diminished': ['dim', 'o'],
#   'dominant_seventh': ['7', 'dom7'],
#   'major_seventh': ['maj7', 'M7', 'j7'],
#   'minor_major_seventh': ['mM7', 'm#7', 'minmaj7', '-j7', '-maj7'],
#   'minor_seventh': ['m7', 'min7', '-7'],
#   'augmented_major_seventh': ['+M7', 'augmaj7', '+j7'],
#   'augmented_seventh': ['7+', '+7', 'aug7'],
#   'half_diminished_seventh': ['ø7', 'm7b5'],
#   'diminished_seventh': ['o7', 'dim7'],
#   'seventh_flat_five': ['dom7dim5'],
#   'major_sixth': ['6'],
#   'minor_sixth': ['m6', 'min6', '-6'],
#   'major_ninth': ['M9', 'Maj9', 'j79'],
#   'dominant_ninth': ['9', 'dom9', '79'],
#   'minor_major_ninth': ['mM9', 'minmaj9', '-j79#'],
#   'minor_ninth': ['m9', 'min9', '-79'],
#   'augmented_major_ninth': ['+M9', 'augmaj9', '+79#', '+79'],
#   'augmented_dominant_ninth': ['9#5', '+9', 'aug9', '+79b'],
#   'half_diminished_ninth': ['ø9'],
#   'half_diminished_minor_ninth': ['øb9'],
#   'diminished_ninth': ['o9', 'dim9'],
#   'diminished_minor_ninth': ['ob9', 'dimb9'],
#   'flat_ninth': ['79b'],
#   'minor_flat_ninth': ['-79b'],
#   'sharp_ninth': ['79#'],
#   'major_sharp_ninth': ['j79#'],
#   'sixth_ninth': ['69'],
#   'minor_sixth_ninth': ['-69'],
#   'dominant_11th': ['11', 'dom11', '7911'],
#   'major_11th': ['M11', 'Maj11', 'j7911'],
#   'minor_major_11th': ['mM11', 'minmaj11'],
#   'minor_11th': ['m11', 'min11', '-7911'],
#   'augmented_major_11th': ['+M11', 'augmaj11'],
#   'augmented_11th': ['+11', 'aug11'],
#   'half_diminished_11th': ['ø11'],
#   'diminished_11th': ['o11', 'dim11'],
#   'major_sharp_11th': ['j7911#'],
#   'sharp_11th': ['7911#'],
#   'augmented_sharp_11th': ['+7911#'],
#   'sharp_ninth_sharp_11th': ['79#11#'],
#   'major_sharp_ninth_sharp_11th': ['j79#11#'],
#   'minor_major_sharp_11th': ['-j7911#'],
#   'sixth_ninth_sharp_eleventh': ['6911#'],
#   'major_13th': ['M13', 'Maj13', '7913'],
#   'dominant_13th': ['13', 'dom13', '79b13'],
#   'minor_major_13th': ['mM13', 'minmaj13', '-j7913'],
#   'minor_13th': ['m13', 'min13', '-7913'],
#   'augmented_major_13th': ['+M13', 'augmaj13'],
#   'augmented_dominant_13th': ['+13', 'aug13'],
#   'half_diminished_13th': ['ø13'],
#   'sharp_ninth_13th': ['79#13'],
#   'flat_13th': ['7913b'],
#   'flat_ninth_flat_13th': ['79b13b'],
#   'suspended_second': ['sus2'],
#   'suspended_fourth': ['sus', 'sus4'],
#   'suspended_fourth_seventh': ['7sus', '7sus4', 'sus7'],
#   'suspended_ninth': ['sus79'],
#   'suspended_thirteen': ['sus7913'],
#   'neapolitan': ['N6'],
#   'italian': ['It+6', 'It'],
#   'french': ['Fr+6', 'Fr'],
#   'german': ['Gr+6', 'Ger'],
#   'pedal': ['pedal'],
#   'power': ['power'],
#   'tristan': ['tristan'],
#   'alt': ['alt', '7alt'],
#   'subtract_degree': ['subtract" altered_degree'],
#   'alter_degree': ['alter" altered_degree'],
#   'add_degree': ['add" altered_degree'],
#   'slash': ['/" altered_note']},
#  'leadsheet_jazz_corpus.lark': {'major': ['', 'M', 'maj', 'j'],
#   'minor': ['m', 'min', '-'],
#   'augmented': ['+', 'aug'],
#   'diminished': ['dim', 'o'],
#   'dominant_seventh': ['7', 'dom7', '%7'],
#   'major_seventh': ['maj7', 'M7', 'j7'],
#   'minor_major_seventh': ['mM7', 'm#7', 'minmaj7', '-j7', '-maj7'],
#   'minor_seventh': ['m7', 'min7', '-7', 'm,M7'],
#   'augmented_major_seventh': ['+M7', 'augmaj7'],
#   'augmented_seventh': ['7+', '+7', 'aug7'],
#   'half_diminished_seventh': ['ø7', 'm7b5'],
#   'diminished_seventh': ['o7', 'dim7'],
#   'seventh_flat_five': ['b5,7'],
#   'major_seventh_flat_five': ['b5,M7'],
#   'major_sixth': ['6'],
#   'minor_sixth': ['m6', 'min6', '-6'],
#   'major_ninth': ['M9', 'Maj9', 'j79'],
#   'dominant_ninth': ['9', 'dom9', '79'],
#   'minor_major_ninth': ['mM9', 'minmaj9', '-j79#'],
#   'minor_ninth': ['m9', 'min9', '-79'],
#   'augmented_major_ninth': ['+M9', 'augmaj9', '+79#', '+79'],
#   'augmented_dominant_ninth': ['9#5', '+9', 'aug9', '+79b'],
#   'half_diminished_ninth': ['ø9'],
#   'half_diminished_minor_ninth': ['øb9'],
#   'diminished_ninth': ['o9', 'dim9'],
#   'diminished_minor_ninth': ['ob9', 'dimb9'],
#   'flat_ninth': ['79b'],
#   'minor_flat_ninth': ['-79b'],
#   'sharp_ninth': ['79#'],
#   'major_sharp_ninth': ['j79#'],
#   'sixth_ninth': ['69'],
#   'minor_sixth_ninth': ['-69'],
#   'dominant_11th': ['11', 'dom11', '7911'],
#   'major_11th': ['M11', 'Maj11', 'j7911'],
#   'minor_major_11th': ['mM11', 'minmaj11'],
#   'minor_11th': ['m11', 'min11', '-7911'],
#   'augmented_major_11th': ['+M11', 'augmaj11'],
#   'augmented_11th': ['+11', 'aug11'],
#   'half_diminished_11th': ['ø11'],
#   'diminished_11th': ['o11', 'dim11'],
#   'major_sharp_11th': ['j7911#'],
#   'sharp_11th': ['7911#'],
#   'augmented_sharp_11th': ['+7911#'],
#   'sharp_ninth_sharp_11th': ['79#11#'],
#   'major_sharp_ninth_sharp_11th': ['j79#11#'],
#   'minor_major_sharp_11th': ['-j7911#'],
#   'sixth_ninth_sharp_eleventh': ['6911#'],
#   'major_13th': ['M13', 'Maj13', '7913'],
#   'dominant_13th': ['13', 'dom13', '79b13'],
#   'minor_major_13th': ['mM13', 'minmaj13', '-j7913'],
#   'minor_13th': ['m13', 'min13', '-7913'],
#   'augmented_major_13th': ['+M13', 'augmaj13'],
#   'augmented_dominant_13th': ['+13', 'aug13'],
#   'half_diminished_13th': ['ø13'],
#   'sharp_ninth_13th': ['79#13'],
#   'flat_13th': ['7913b'],
#   'flat_ninth_flat_13th': ['79b13b'],
#   'suspended_second': ['sus2'],
#   'suspended_fourth': ['sus', 'sus4'],
#   'suspended_fourth_seventh': ['7sus', '7sus4', 'sus7', 'sus4,7'],
#   'suspended_ninth': ['sus79'],
#   'suspended_thirteen': ['sus7913'],
#   'neapolitan': ['N6'],
#   'italian': ['It+6', 'It'],
#   'french': ['Fr+6', 'Fr'],
#   'german': ['Gr+6', 'Ger'],
#   'pedal': ['pedal'],
#   'power': ['power'],
#   'tristan': ['tristan'],
#   'alt': ['alt', '7alt'],
#   'subtract_degree': ['subtract" altered_degree'],
#   'alter_degree': ['alter" altered_degree'],
#   'add_degree': ['add" altered_degree'],
#   'slash': ['/" altered_note']},
#  'leadsheet_music21.lark': {'major': ['', 'M', 'maj'],
#   'minor': ['m', 'min'],
#   'augmented': ['+', 'aug'],
#   'diminished': ['dim', 'o'],
#   'dominant_seventh': ['7', 'dom7'],
#   'major_seventh': ['maj7', 'M7'],
#   'minor_major_seventh': ['mM7', 'm#7', 'minmaj7'],
#   'minor_seventh': ['m7', 'min7'],
#   'augmented_major_seventh': ['+M7', 'augmaj7'],
#   'augmented_seventh': ['7+', '+7', 'aug7'],
#   'half_diminished_seventh': ['ø7', 'm7b5'],
#   'diminished_seventh': ['o7', 'dim7'],
#   'seventh_flat_five': ['dom7dim5'],
#   'major_sixth': ['6'],
#   'minor_sixth': ['m6', 'min6'],
#   'major_ninth': ['M9', 'Maj9'],
#   'dominant_ninth': ['9', 'dom9'],
#   'minor_major_ninth': ['mM9', 'minmaj9'],
#   'minor_ninth': ['m9', 'min9'],
#   'augmented_major_ninth': ['+M9', 'augmaj9'],
#   'augmented_dominant_ninth': ['9#5', '+9', 'aug9'],
#   'half_diminished_ninth': ['ø9'],
#   'half_diminished_minor_ninth': ['øb9'],
#   'diminished_ninth': ['o9', 'dim9'],
#   'diminished_minor_ninth': ['ob9', 'dimb9'],
#   'dominant_11th': ['11', 'dom11'],
#   'major_11th': ['M11', 'Maj11'],
#   'minor_major_11th': ['mM11', 'minmaj11'],
#   'minor_11th': ['m11', 'min11'],
#   'augmented_major_11th': ['+M11', 'augmaj11'],
#   'augmented_11th': ['+11', 'aug11'],
#   'half_diminished_11th': ['ø11'],
#   'diminished_11th': ['o11', 'dim11'],
#   'major_13th': ['M13', 'Maj13'],
#   'dominant_13th': ['13', 'dom13'],
#   'minor_major_13th': ['mM13', 'minmaj13'],
#   'minor_13th': ['m13', 'min13'],
#   'augmented_major_13th': ['+M13', 'augmaj13'],
#   'augmented_dominant_13th': ['+13', 'aug13'],
#   'half_diminished_13th': ['ø13'],
#   'suspended_second': ['sus2'],
#   'suspended_fourth': ['sus', 'sus4'],
#   'suspended_fourth_seventh': ['7sus', '7sus4'],
#   'neapolitan': ['N6'],
#   'italian': ['It+6', 'It'],
#   'french': ['Fr+6', 'Fr'],
#   'german': ['Gr+6', 'Ger'],
#   'pedal': ['pedal'],
#   'power': ['power'],
#   'tristan': ['tristan'],
#   'subtract_degree': ['subtract" altered_degree'],
#   'alter_degree': ['alter" altered_degree'],
#   'add_degree': ['add" altered_degree'],
#   'slash': ['/" altered_note']},
#  'leadsheet_ireal.lark': {'major': ['', 'M', 'maj', '^', 'aj'],
#   'minor': ['m', 'min', '-'],
#   'augmented': ['+', 'aug', '7#5', 'ug', '5+', '+5'],
#   'minor_augmented': ['-7#5', '-#5'],
#   'diminished': ['dim', 'o', 'im', '-b5'],
#   'dominant_seventh': ['7', 'dom7', 'h7'],
#   'major_seventh': ['maj7', 'M7', '^7', 'aj7', '7#'],
#   'minor_major_seventh': ['mM7', 'm#7', 'minmaj7', '-^7'],
#   'minor_seventh': ['m7', 'min7', '-7', 'im7'],
#   'augmented_major_seventh': ['+M7', 'augmaj7', '^7#5'],
#   'augmented_seventh': ['7+', '+7', 'aug7'],
#   'half_diminished_seventh': ['ø7', '-7b5', '7b5'],
#   'diminished_seventh': ['o7', 'dim7'],
#   'diminished_seventh_major_seventh': ['o^7'],
#   'seventh_flat_five': ['dom7dim5'],
#   'major_seventh_flat_five': ['^7#5'],
#   'major_sixth': ['6'],
#   'minor_sixth': ['m6', 'min6', '-6'],
#   'minor_flat_sixth': ['-b6'],
#   'major_ninth': ['M9', 'Maj9', '79#'],
#   'dominant_ninth': ['9', 'dom9', '79', '^9', 'aj9'],
#   'minor_major_ninth': ['mM9', 'minmaj9', '-^9'],
#   'minor_ninth': ['m9', 'min9', '-9', '-79'],
#   'augmented_major_ninth': ['+M9', 'augmaj9', '#5#9'],
#   'augmented_sharp_ninth': ['7#9#5', '+79#'],
#   'augmented_dominant_ninth': ['9#5', '+9', 'aug9'],
#   'half_diminished_ninth': ['ø9'],
#   'half_diminished_minor_ninth': ['øb9'],
#   'diminished_ninth': ['o9', 'dim9'],
#   'diminished_minor_ninth': ['ob9', 'dimb9'],
#   'flat_ninth': ['7b9'],
#   'minor_flat_ninth': ['-7b9'],
#   'sharp_ninth': ['7#9'],
#   'major_sharp_ninth': ['^7#'],
#   'sixth_ninth': ['69'],
#   'minor_sixth_ninth': ['-69'],
#   'sharp_7th_flat_5th_flat_9th': ['#7b9b5'],
#   'seventh_flat_9th_sharp_9th': ['7b9#9', 'b9b5'],
#   'seventh_sharp_9th_flat_5th': ['7#9b5', '#9b5'],
#   'seventh_flat_9th_flat_5th': ['7b9b5', 'b9b5', 'b7b9b5'],
#   'seventh_flat_9th_sharp_5th': ['7b9#5', 'b9#5'],
#   'flat_fifth_9th': ['9b5', 'b7b9b5'],
#   'dominant_11th': ['11', 'dom11'],
#   'major_11th': ['M11', 'Maj11'],
#   'minor_major_11th': ['mM11', 'minmaj11'],
#   'minor_11th': ['m11', 'min11', '-7911', '-7911', '-11'],
#   'augmented_major_11th': ['+M11', 'augmaj11', 'j7911#'],
#   'augmented_11th': ['+11', 'aug11', '7911#'],
#   'half_diminished_11th': ['ø11'],
#   'diminished_11th': ['o11', 'dim11'],
#   'major_sharp_11th': ['^79#11', '^7#11'],
#   'sharp_11th': ['79#11', '7#11', '9#11'],
#   'augmented_sharp_11th': ['+79#11'],
#   'sharp_ninth_sharp_11th': ['7#9#11'],
#   'major_sharp_ninth_sharp_11th': ['^7#9#11'],
#   'minor_major_sharp_11th': ['-^79#11'],
#   'sixth_ninth_sharp_eleventh': ['69#11'],
#   'flat_ninth_sharp_11th': ['7b9#11', 'b9#11'],
#   'major_ninth_sharp_11th': ['^9#11'],
#   'major_13th': ['M13', 'Maj13', '^13'],
#   'dominant_13th': ['13', 'dom13', '7913', '713', '913'],
#   'minor_major_13th': ['mM13', 'minmaj13'],
#   'minor_13th': ['m13', 'min13', '-13'],
#   'augmented_major_13th': ['+M13', 'augmaj13'],
#   'augmented_dominant_13th': ['+13', 'aug13'],
#   'half_diminished_13th': ['ø13'],
#   'sharp_ninth_13th': ['7#913', '13#9'],
#   'flat_ninth_sharp_13th': ['#13b9'],
#   'flat_13th': ['79b13', '7b13'],
#   'flat_ninth_flat_13th': ['7b9b13', 'b13b9'],
#   'flat_13th_sharp_11th': ['b13#11'],
#   'flat_ninth_13th': ['13b9'],
#   'sharp_eleventh_13th': ['13#11'],
#   'sharp_ninth_sharp_13th': ['7#9#13', '#9#13', '#13#9'],
#   'sharp_ninth_flat_13th': ['7#9b13', 'b13#9', '#9b13'],
#   'suspended_second': ['sus2', '2', 'us2'],
#   'suspended_fourth': ['sus', 'sus4', 'sus', 'us', 'us4'],
#   'suspended_fourth_seventh': ['7sus', '7sus4', 'sus7', 'us7'],
#   'suspended_ninth': ['sus79', 'sus9', '9sus', 'us9'],
#   'suspended_flat_ninth': ['7b9sus', 'usb9'],
#   'suspended_thirteen': ['sus7913', 'sus13', '13sus', 'us13'],
#   'suspended_flat_thirteen': ['b7b13sus', '7b13sus'],
#   'neapolitan': ['N6'],
#   'italian': ['It+6', 'It'],
#   'french': ['Fr+6', 'Fr'],
#   'german': ['Gr+6', 'Ger'],
#   'pedal': ['pedal'],
#   'power': ['power', '5', '-5'],
#   'tristan': ['tristan'],
#   'alt': ['alt', '7alt', '7at'],
#   'subtract_degree': ['subtract" altered_degree'],
#   'alter_degree': ['alter" altered_degree'],
#   'add_degree': ['add" altered_degree', 'dd" altered_degree'],
#   'slash': ['/" altered_note']}}

# %% [markdown]
# ## Get chord grades

# %%
import sys
import pandas as pd

sys.path.append(os.path.join(os.getcwd(), '..', 'lark-converters'))
sys.path.append(os.path.join(os.getcwd(), '..'))

from lark_to_harte import MISSING_INTERVALS, HARTE_SHORTHAND_MAP
from music21 import harmony

print(harmony.CHORD_TYPES['major'][0].replace('-', 'b'))

for grammar_name, grammar_shorts in all_grammars.items():
    short_grades = []
    print(grammar_name, '\n')
    for short_name, short_variants in grammar_shorts.items():
        short_name = short_name.replace('_', '-')
        # print(short_name, MISSING_INTERVALS.keys())
        if short_name in harmony.CHORD_TYPES.keys():
            short_grades.append([short_name, short_variants, harmony.CHORD_TYPES['major'][0].replace('-', 'b')])
        if short_name in MISSING_INTERVALS.keys():
            short_grades.append([short_name, short_variants, MISSING_INTERVALS[short_name].replace('-', 'b')])

        df = pd.DataFrame(short_grades, columns=['chord_name', 'shorthands', 'grades_harte'])
        writer = pd.ExcelWriter(f'validation_{grammar_name.rstrip(".lark")}.xlsx', engine='xlsxwriter')
        df.to_excel(writer, sheet_name=grammar_name, index=False)
        writer.save()

    print(short_grades)
# Out:
# 1,3,5
# abc_music21.lark
#
# [['major', ['', 'M', 'maj'], '1,3,5'], ['minor', ['m', 'min'], '1,3,5'], ['augmented', ['+', 'aug'], '1,3,5'], ['diminished', ['dim', 'o'], '1,3,5'], ['dominant-seventh', ['7', 'dom7'], '1,3,5'], ['major-seventh', ['maj7', 'M7'], '1,3,5'], ['minor-major-seventh', ['mM7', 'm#7', 'minmaj7'], '1,3,5'], ['minor-seventh', ['m7', 'min7'], '1,3,5'], ['augmented-major-seventh', ['+M7', 'augmaj7'], '1,3,5'], ['augmented-seventh', ['7+', '+7', 'aug7'], '1,3,5'], ['half-diminished-seventh', ['ø7', 'm7b5'], '1,3,5'], ['diminished-seventh', ['o7', 'dim7'], '1,3,5'], ['seventh-flat-five', ['dom7dim5'], '1,3,5'], ['major-sixth', ['6'], '1,3,5'], ['minor-sixth', ['m6', 'min6'], '1,3,5'], ['major-ninth', ['M9', 'Maj9'], '1,3,5'], ['dominant-ninth', ['9', 'dom9'], '1,3,5'], ['minor-major-ninth', ['mM9', 'minmaj9'], '1,3,5'], ['minor-ninth', ['m9', 'min9'], '1,3,5'], ['augmented-major-ninth', ['+M9', 'augmaj9'], '1,3,5'], ['augmented-dominant-ninth', ['9#5', '+9', 'aug9'], '1,3,5'], ['half-diminished-ninth', ['ø9'], '1,3,5'], ['half-diminished-minor-ninth', ['øb9'], '1,3,5'], ['diminished-ninth', ['o9', 'dim9'], '1,3,5'], ['diminished-minor-ninth', ['ob9', 'dimb9'], '1,3,5'], ['dominant-11th', ['11', 'dom11'], '1,3,5'], ['major-11th', ['M11', 'Maj11'], '1,3,5'], ['minor-major-11th', ['mM11', 'minmaj11'], '1,3,5'], ['minor-11th', ['m11', 'min11'], '1,3,5'], ['augmented-major-11th', ['+M11', 'augmaj11'], '1,3,5'], ['augmented-11th', ['+11', 'aug11'], '1,3,5'], ['half-diminished-11th', ['ø11'], '1,3,5'], ['diminished-11th', ['o11', 'dim11'], '1,3,5'], ['major-13th', ['M13', 'Maj13'], '1,3,5'], ['dominant-13th', ['13', 'dom13'], '1,3,5'], ['minor-major-13th', ['mM13', 'minmaj13'], '1,3,5'], ['minor-13th', ['m13', 'min13'], '1,3,5'], ['augmented-major-13th', ['+M13', 'augmaj13'], '1,3,5'], ['augmented-dominant-13th', ['+13', 'aug13'], '1,3,5'], ['half-diminished-13th', ['ø13'], '1,3,5'], ['suspended-second', ['sus2'], '1,3,5'], ['suspended-fourth', ['sus', 'sus4'], '1,3,5'], ['suspended-fourth-seventh', ['7sus', '7sus4'], '1,3,5'], ['pedal', ['pedal'], '1,3,5'], ['power', ['power'], '1,3,5']]
# leadsheet_weimar.lark
#
# [['major', ['', 'M', 'maj', 'j'], '1,3,5'], ['minor', ['m', 'min', '-'], '1,3,5'], ['augmented', ['+', 'aug'], '1,3,5'], ['diminished', ['dim', 'o'], '1,3,5'], ['dominant-seventh', ['7', 'dom7'], '1,3,5'], ['major-seventh', ['maj7', 'M7', 'j7'], '1,3,5'], ['minor-major-seventh', ['mM7', 'm#7', 'minmaj7', '-j7', '-maj7'], '1,3,5'], ['minor-seventh', ['m7', 'min7', '-7'], '1,3,5'], ['augmented-major-seventh', ['+M7', 'augmaj7', '+j7'], '1,3,5'], ['augmented-seventh', ['7+', '+7', 'aug7'], '1,3,5'], ['half-diminished-seventh', ['ø7', 'm7b5'], '1,3,5'], ['diminished-seventh', ['o7', 'dim7'], '1,3,5'], ['seventh-flat-five', ['dom7dim5'], '1,3,5'], ['major-sixth', ['6'], '1,3,5'], ['minor-sixth', ['m6', 'min6', '-6'], '1,3,5'], ['major-ninth', ['M9', 'Maj9', 'j79'], '1,3,5'], ['dominant-ninth', ['9', 'dom9', '79'], '1,3,5'], ['minor-major-ninth', ['mM9', 'minmaj9', '-j79#'], '1,3,5'], ['minor-ninth', ['m9', 'min9', '-79'], '1,3,5'], ['augmented-major-ninth', ['+M9', 'augmaj9', '+79#', '+79'], '1,3,5'], ['augmented-dominant-ninth', ['9#5', '+9', 'aug9', '+79b'], '1,3,5'], ['half-diminished-ninth', ['ø9'], '1,3,5'], ['half-diminished-minor-ninth', ['øb9'], '1,3,5'], ['diminished-ninth', ['o9', 'dim9'], '1,3,5'], ['diminished-minor-ninth', ['ob9', 'dimb9'], '1,3,5'], ['flat-ninth', ['79b'], '1,3,5,b7,b9'], ['minor-flat-ninth', ['-79b'], '1,b3,5,b7,b9'], ['sharp-ninth', ['79#'], '1,3,5,b7,#9'], ['major-sharp-ninth', ['j79#'], '1,3,5,7,#9'], ['sixth-ninth', ['69'], '1,3,5,6,9'], ['minor-sixth-ninth', ['-69'], '1,b3,5,6,9'], ['dominant-11th', ['11', 'dom11', '7911'], '1,3,5'], ['major-11th', ['M11', 'Maj11', 'j7911'], '1,3,5'], ['minor-major-11th', ['mM11', 'minmaj11'], '1,3,5'], ['minor-11th', ['m11', 'min11', '-7911'], '1,3,5'], ['augmented-major-11th', ['+M11', 'augmaj11'], '1,3,5'], ['augmented-11th', ['+11', 'aug11'], '1,3,5'], ['half-diminished-11th', ['ø11'], '1,3,5'], ['diminished-11th', ['o11', 'dim11'], '1,3,5'], ['major-sharp-11th', ['j7911#'], '1,3,5,7,9,#11'], ['sharp-11th', ['7911#'], '1,3,5,b7,9,#11'], ['augmented-sharp-11th', ['+7911#'], '1,3,#5,b7,9,#11'], ['sharp-ninth-sharp-11th', ['79#11#'], '1,3,5,b7,#9,#11'], ['major-sharp-ninth-sharp-11th', ['j79#11#'], '1,3,5,7,#9,#11'], ['minor-major-sharp-11th', ['-j7911#'], '1,b3,5,7,9,#11'], ['sixth-ninth-sharp-eleventh', ['6911#'], '1,3,5,6,9,#11'], ['major-13th', ['M13', 'Maj13', '7913'], '1,3,5'], ['dominant-13th', ['13', 'dom13', '79b13'], '1,3,5'], ['minor-major-13th', ['mM13', 'minmaj13', '-j7913'], '1,3,5'], ['minor-13th', ['m13', 'min13', '-7913'], '1,3,5'], ['augmented-major-13th', ['+M13', 'augmaj13'], '1,3,5'], ['augmented-dominant-13th', ['+13', 'aug13'], '1,3,5'], ['half-diminished-13th', ['ø13'], '1,3,5'], ['sharp-ninth-13th', ['79#13'], '1,3,5,b7,#9,13'], ['flat-13th', ['7913b'], '1,3,5,b7,9,b13'], ['flat-ninth-flat-13th', ['79b13b'], '1,3,5,b7,b9,b13'], ['suspended-second', ['sus2'], '1,3,5'], ['suspended-fourth', ['sus', 'sus4'], '1,3,5'], ['suspended-fourth-seventh', ['7sus', '7sus4', 'sus7'], '1,3,5'], ['suspended-ninth', ['sus79'], '1,4,5,b7,9'], ['suspended-thirteen', ['sus7913'], '1,4,5,b7,9,11,13'], ['pedal', ['pedal'], '1,3,5'], ['power', ['power'], '1,3,5'], ['alt', ['alt', '7alt'], '1,3,b5,b7,b9,b13']]
# leadsheet_jazz_corpus.lark
#
# [['major', ['', 'M', 'maj', 'j'], '1,3,5'], ['minor', ['m', 'min', '-'], '1,3,5'], ['augmented', ['+', 'aug'], '1,3,5'], ['diminished', ['dim', 'o'], '1,3,5'], ['dominant-seventh', ['7', 'dom7', '%7'], '1,3,5'], ['major-seventh', ['maj7', 'M7', 'j7'], '1,3,5'], ['minor-major-seventh', ['mM7', 'm#7', 'minmaj7', '-j7', '-maj7'], '1,3,5'], ['minor-seventh', ['m7', 'min7', '-7', 'm,M7'], '1,3,5'], ['augmented-major-seventh', ['+M7', 'augmaj7'], '1,3,5'], ['augmented-seventh', ['7+', '+7', 'aug7'], '1,3,5'], ['half-diminished-seventh', ['ø7', 'm7b5'], '1,3,5'], ['diminished-seventh', ['o7', 'dim7'], '1,3,5'], ['seventh-flat-five', ['b5,7'], '1,3,5'], ['major-seventh-flat-five', ['b5,M7'], '1,3,b5,7'], ['major-sixth', ['6'], '1,3,5'], ['minor-sixth', ['m6', 'min6', '-6'], '1,3,5'], ['major-ninth', ['M9', 'Maj9', 'j79'], '1,3,5'], ['dominant-ninth', ['9', 'dom9', '79'], '1,3,5'], ['minor-major-ninth', ['mM9', 'minmaj9', '-j79#'], '1,3,5'], ['minor-ninth', ['m9', 'min9', '-79'], '1,3,5'], ['augmented-major-ninth', ['+M9', 'augmaj9', '+79#', '+79'], '1,3,5'], ['augmented-dominant-ninth', ['9#5', '+9', 'aug9', '+79b'], '1,3,5'], ['half-diminished-ninth', ['ø9'], '1,3,5'], ['half-diminished-minor-ninth', ['øb9'], '1,3,5'], ['diminished-ninth', ['o9', 'dim9'], '1,3,5'], ['diminished-minor-ninth', ['ob9', 'dimb9'], '1,3,5'], ['flat-ninth', ['79b'], '1,3,5,b7,b9'], ['minor-flat-ninth', ['-79b'], '1,b3,5,b7,b9'], ['sharp-ninth', ['79#'], '1,3,5,b7,#9'], ['major-sharp-ninth', ['j79#'], '1,3,5,7,#9'], ['sixth-ninth', ['69'], '1,3,5,6,9'], ['minor-sixth-ninth', ['-69'], '1,b3,5,6,9'], ['dominant-11th', ['11', 'dom11', '7911'], '1,3,5'], ['major-11th', ['M11', 'Maj11', 'j7911'], '1,3,5'], ['minor-major-11th', ['mM11', 'minmaj11'], '1,3,5'], ['minor-11th', ['m11', 'min11', '-7911'], '1,3,5'], ['augmented-major-11th', ['+M11', 'augmaj11'], '1,3,5'], ['augmented-11th', ['+11', 'aug11'], '1,3,5'], ['half-diminished-11th', ['ø11'], '1,3,5'], ['diminished-11th', ['o11', 'dim11'], '1,3,5'], ['major-sharp-11th', ['j7911#'], '1,3,5,7,9,#11'], ['sharp-11th', ['7911#'], '1,3,5,b7,9,#11'], ['augmented-sharp-11th', ['+7911#'], '1,3,#5,b7,9,#11'], ['sharp-ninth-sharp-11th', ['79#11#'], '1,3,5,b7,#9,#11'], ['major-sharp-ninth-sharp-11th', ['j79#11#'], '1,3,5,7,#9,#11'], ['minor-major-sharp-11th', ['-j7911#'], '1,b3,5,7,9,#11'], ['sixth-ninth-sharp-eleventh', ['6911#'], '1,3,5,6,9,#11'], ['major-13th', ['M13', 'Maj13', '7913'], '1,3,5'], ['dominant-13th', ['13', 'dom13', '79b13'], '1,3,5'], ['minor-major-13th', ['mM13', 'minmaj13', '-j7913'], '1,3,5'], ['minor-13th', ['m13', 'min13', '-7913'], '1,3,5'], ['augmented-major-13th', ['+M13', 'augmaj13'], '1,3,5'], ['augmented-dominant-13th', ['+13', 'aug13'], '1,3,5'], ['half-diminished-13th', ['ø13'], '1,3,5'], ['sharp-ninth-13th', ['79#13'], '1,3,5,b7,#9,13'], ['flat-13th', ['7913b'], '1,3,5,b7,9,b13'], ['flat-ninth-flat-13th', ['79b13b'], '1,3,5,b7,b9,b13'], ['suspended-second', ['sus2'], '1,3,5'], ['suspended-fourth', ['sus', 'sus4'], '1,3,5'], ['suspended-fourth-seventh', ['7sus', '7sus4', 'sus7', 'sus4,7'], '1,3,5'], ['suspended-ninth', ['sus79'], '1,4,5,b7,9'], ['suspended-thirteen', ['sus7913'], '1,4,5,b7,9,11,13'], ['pedal', ['pedal'], '1,3,5'], ['power', ['power'], '1,3,5'], ['alt', ['alt', '7alt'], '1,3,b5,b7,b9,b13']]
# leadsheet_music21.lark
#
# [['major', ['', 'M', 'maj'], '1,3,5'], ['minor', ['m', 'min'], '1,3,5'], ['augmented', ['+', 'aug'], '1,3,5'], ['diminished', ['dim', 'o'], '1,3,5'], ['dominant-seventh', ['7', 'dom7'], '1,3,5'], ['major-seventh', ['maj7', 'M7'], '1,3,5'], ['minor-major-seventh', ['mM7', 'm#7', 'minmaj7'], '1,3,5'], ['minor-seventh', ['m7', 'min7'], '1,3,5'], ['augmented-major-seventh', ['+M7', 'augmaj7'], '1,3,5'], ['augmented-seventh', ['7+', '+7', 'aug7'], '1,3,5'], ['half-diminished-seventh', ['ø7', 'm7b5'], '1,3,5'], ['diminished-seventh', ['o7', 'dim7'], '1,3,5'], ['seventh-flat-five', ['dom7dim5'], '1,3,5'], ['major-sixth', ['6'], '1,3,5'], ['minor-sixth', ['m6', 'min6'], '1,3,5'], ['major-ninth', ['M9', 'Maj9'], '1,3,5'], ['dominant-ninth', ['9', 'dom9'], '1,3,5'], ['minor-major-ninth', ['mM9', 'minmaj9'], '1,3,5'], ['minor-ninth', ['m9', 'min9'], '1,3,5'], ['augmented-major-ninth', ['+M9', 'augmaj9'], '1,3,5'], ['augmented-dominant-ninth', ['9#5', '+9', 'aug9'], '1,3,5'], ['half-diminished-ninth', ['ø9'], '1,3,5'], ['half-diminished-minor-ninth', ['øb9'], '1,3,5'], ['diminished-ninth', ['o9', 'dim9'], '1,3,5'], ['diminished-minor-ninth', ['ob9', 'dimb9'], '1,3,5'], ['dominant-11th', ['11', 'dom11'], '1,3,5'], ['major-11th', ['M11', 'Maj11'], '1,3,5'], ['minor-major-11th', ['mM11', 'minmaj11'], '1,3,5'], ['minor-11th', ['m11', 'min11'], '1,3,5'], ['augmented-major-11th', ['+M11', 'augmaj11'], '1,3,5'], ['augmented-11th', ['+11', 'aug11'], '1,3,5'], ['half-diminished-11th', ['ø11'], '1,3,5'], ['diminished-11th', ['o11', 'dim11'], '1,3,5'], ['major-13th', ['M13', 'Maj13'], '1,3,5'], ['dominant-13th', ['13', 'dom13'], '1,3,5'], ['minor-major-13th', ['mM13', 'minmaj13'], '1,3,5'], ['minor-13th', ['m13', 'min13'], '1,3,5'], ['augmented-major-13th', ['+M13', 'augmaj13'], '1,3,5'], ['augmented-dominant-13th', ['+13', 'aug13'], '1,3,5'], ['half-diminished-13th', ['ø13'], '1,3,5'], ['suspended-second', ['sus2'], '1,3,5'], ['suspended-fourth', ['sus', 'sus4'], '1,3,5'], ['suspended-fourth-seventh', ['7sus', '7sus4'], '1,3,5'], ['pedal', ['pedal'], '1,3,5'], ['power', ['power'], '1,3,5']]
# leadsheet_ireal.lark
#
# [['major', ['', 'M', 'maj', '^', 'aj'], '1,3,5'], ['minor', ['m', 'min', '-'], '1,3,5'], ['augmented', ['+', 'aug', '7#5', 'ug', '5+', '+5'], '1,3,5'], ['minor-augmented', ['-7#5', '-#5'], '1,b3,#5'], ['diminished', ['dim', 'o', 'im', '-b5'], '1,3,5'], ['dominant-seventh', ['7', 'dom7', 'h7'], '1,3,5'], ['major-seventh', ['maj7', 'M7', '^7', 'aj7', '7#'], '1,3,5'], ['minor-major-seventh', ['mM7', 'm#7', 'minmaj7', '-^7'], '1,3,5'], ['minor-seventh', ['m7', 'min7', '-7', 'im7'], '1,3,5'], ['augmented-major-seventh', ['+M7', 'augmaj7', '^7#5'], '1,3,5'], ['augmented-seventh', ['7+', '+7', 'aug7'], '1,3,5'], ['half-diminished-seventh', ['ø7', '-7b5', '7b5'], '1,3,5'], ['diminished-seventh', ['o7', 'dim7'], '1,3,5'], ['diminished-seventh-major-seventh', ['o^7'], '1,b3,b5,7'], ['seventh-flat-five', ['dom7dim5'], '1,3,5'], ['major-seventh-flat-five', ['^7#5'], '1,3,b5,7'], ['major-sixth', ['6'], '1,3,5'], ['minor-sixth', ['m6', 'min6', '-6'], '1,3,5'], ['minor-flat-sixth', ['-b6'], '1,b3,5,b6'], ['major-ninth', ['M9', 'Maj9', '79#'], '1,3,5'], ['dominant-ninth', ['9', 'dom9', '79', '^9', 'aj9'], '1,3,5'], ['minor-major-ninth', ['mM9', 'minmaj9', '-^9'], '1,3,5'], ['minor-ninth', ['m9', 'min9', '-9', '-79'], '1,3,5'], ['augmented-major-ninth', ['+M9', 'augmaj9', '#5#9'], '1,3,5'], ['augmented-sharp-ninth', ['7#9#5', '+79#'], '1,3,#5,b7,#9'], ['augmented-dominant-ninth', ['9#5', '+9', 'aug9'], '1,3,5'], ['half-diminished-ninth', ['ø9'], '1,3,5'], ['half-diminished-minor-ninth', ['øb9'], '1,3,5'], ['diminished-ninth', ['o9', 'dim9'], '1,3,5'], ['diminished-minor-ninth', ['ob9', 'dimb9'], '1,3,5'], ['flat-ninth', ['7b9'], '1,3,5,b7,b9'], ['minor-flat-ninth', ['-7b9'], '1,b3,5,b7,b9'], ['sharp-ninth', ['7#9'], '1,3,5,b7,#9'], ['major-sharp-ninth', ['^7#'], '1,3,5,7,#9'], ['sixth-ninth', ['69'], '1,3,5,6,9'], ['minor-sixth-ninth', ['-69'], '1,b3,5,6,9'], ['sharp-7th-flat-5th-flat-9th', ['#7b9b5'], '1,3,b5,#7,b9'], ['seventh-flat-9th-sharp-9th', ['7b9#9', 'b9b5'], '1,3,5,7,b9,#9'], ['seventh-sharp-9th-flat-5th', ['7#9b5', '#9b5'], '1,3,b5,b7,b9'], ['seventh-flat-9th-flat-5th', ['7b9b5', 'b9b5', 'b7b9b5'], '1,3,b5,b7,9'], ['seventh-flat-9th-sharp-5th', ['7b9#5', 'b9#5'], '1,3,#5,7,b9'], ['flat-fifth-9th', ['9b5', 'b7b9b5'], '1,3,b5,b7,9'], ['dominant-11th', ['11', 'dom11'], '1,3,5'], ['major-11th', ['M11', 'Maj11'], '1,3,5'], ['minor-major-11th', ['mM11', 'minmaj11'], '1,3,5'], ['minor-11th', ['m11', 'min11', '-7911', '-7911', '-11'], '1,3,5'], ['augmented-major-11th', ['+M11', 'augmaj11', 'j7911#'], '1,3,5'], ['augmented-11th', ['+11', 'aug11', '7911#'], '1,3,5'], ['half-diminished-11th', ['ø11'], '1,3,5'], ['diminished-11th', ['o11', 'dim11'], '1,3,5'], ['major-sharp-11th', ['^79#11', '^7#11'], '1,3,5,7,9,#11'], ['sharp-11th', ['79#11', '7#11', '9#11'], '1,3,5,b7,9,#11'], ['augmented-sharp-11th', ['+79#11'], '1,3,#5,b7,9,#11'], ['sharp-ninth-sharp-11th', ['7#9#11'], '1,3,5,b7,#9,#11'], ['major-sharp-ninth-sharp-11th', ['^7#9#11'], '1,3,5,7,#9,#11'], ['minor-major-sharp-11th', ['-^79#11'], '1,b3,5,7,9,#11'], ['sixth-ninth-sharp-eleventh', ['69#11'], '1,3,5,6,9,#11'], ['flat-ninth-sharp-11th', ['7b9#11', 'b9#11'], '1,3,5,b7,b9,#11'], ['major-ninth-sharp-11th', ['^9#11'], '1,3,5,7,9,#11'], ['major-13th', ['M13', 'Maj13', '^13'], '1,3,5'], ['dominant-13th', ['13', 'dom13', '7913', '713', '913'], '1,3,5'], ['minor-major-13th', ['mM13', 'minmaj13'], '1,3,5'], ['minor-13th', ['m13', 'min13', '-13'], '1,3,5'], ['augmented-major-13th', ['+M13', 'augmaj13'], '1,3,5'], ['augmented-dominant-13th', ['+13', 'aug13'], '1,3,5'], ['half-diminished-13th', ['ø13'], '1,3,5'], ['sharp-ninth-13th', ['7#913', '13#9'], '1,3,5,b7,#9,13'], ['flat-ninth-sharp-13th', ['#13b9'], '1,3,5,b7,b9,#13'], ['flat-13th', ['79b13', '7b13'], '1,3,5,b7,9,b13'], ['flat-ninth-flat-13th', ['7b9b13', 'b13b9'], '1,3,5,b7,b9,b13'], ['flat-13th-sharp-11th', ['b13#11'], '1,3,5,b7,9,#11,b13'], ['flat-ninth-13th', ['13b9'], '1,3,5,b7,b9,13'], ['sharp-eleventh-13th', ['13#11'], '1,3,5,b7,9 ...
